# %% [markdown]
# ## ElasticSearch index

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(
    cloud_id=cloud_id,
    api_key=api_key
)

# %%
# Specify the index name
# index_name = "test_index_rec"
index_name = "test_index_nlp"

# %%
# Define index settings and mappings
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "vector": {"type": "dense_vector", "dims": 1536},  # Assuming 1536 dimensions for the embedding
            "text": {"type": "text"}, 
            "metadata": {"type" : "object",
                "properties" : {
                    "id" : {"type" : "text"},
                    "source" : {"type" : "text"},
                    "page" : {"type" : "integer"}
                }
            }
        }
    }
}

# Create the index
es.indices.create(index=index_name, body=index_settings)

# Verify if the index is created
if es.indices.exists(index=index_name):
    print(f"Index '{index_name}' created successfully.")
else:
    print(f"Failed to create index '{index_name}'.")
# Out:
# Index 'test_index_nlp' created successfully.

# %% [markdown]
# ## Embedding

# %%
from langchain.docstore.document import Document
import fitz  # PyMuPDF

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    # get only file name out of the file path
    file_name = pdf_path.split('\\')[-1]
    docs = []
    for page_num in range(doc.page_count):
        page = doc[page_num]
        docs.append(Document(page_content=page.get_text(), metadata={'page': page_num, 'source': file_name}))
    doc.close()

    return docs

def process_pdfs_in_folder(folder_path):
    all_docs = []
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        print(file_path)
        if os.path.isdir(file_path):
            # If it's a folder, call the function recursively
            process_pdfs_in_folder(file_path)
        elif filename.endswith(".pdf"):
            pdf_path = os.path.join(folder_path, filename)
            docs = extract_text_from_pdf(pdf_path)
            all_docs.append(docs)
    return all_docs

# %%
# Set your folder path, chunk size, and overlap
folder_path = "sample"

loaded_documents = process_pdfs_in_folder(folder_path)
# convert list of lists to a single list
loaded_documents = [item for sublist in loaded_documents for item in sublist]

print(f"Length of loaded pages: {len(loaded_documents)}")
# Out:
# sample\AFM_annualreport_2022.pdf
# sample\mckinsey-tech-trends-outlook-2022-full-report.pdf
# sample\mgi-reinventing-construction-a-route-to-higher-productivity-full-report.pdf
# sample\Procter&Gamble_annualreport_2023.pdf
# sample\the-state-of-organizations-2023.pdf
# Length of loaded pages: 724

# %%
from langchain.text_splitter import SpacyTextSplitter
from langchain.text_splitter import RecursiveCharacterTextSplitter

# split docs in chunks
text_splitter = SpacyTextSplitter(
# text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=512,
    chunk_overlap=64
)

nlp_texts = text_splitter.split_documents(loaded_documents)
# Out:
# C:\Users\marti\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# Created a chunk of size 558, which is longer than the specified 512
# Created a chunk of size 730, which is longer than the specified 512
# Created a chunk of size 710, which is longer than the specified 512
# Created a chunk of size 846, which is longer than the specified 512
# Created a chunk of size 659, which is longer than the specified 512
# Created a chunk of size 832, which is longer than the specified 512
# Created a chunk of size 614, which is longer than the specified 512
# Created a chunk of size 671, which is longer than the specified 512
# Created a chunk of size 628, which is longer than the specified 512
# Created a chunk of size 741, which is longer than the specified 512
# Created a chunk of size 531, which is longer than the specified 512
# Created a chunk of size 626, which is longer than the specified 512
# Created a chunk of size 591, which is longer than the specified 512
# Created a chunk of size 559, which is longer than the specified 512
# Created a chunk of size 764, which is longer than the specified 512
# Created a chunk of size 612, which is longer than the specified 512
# Created a chunk of size 576, which is longer than the specified 512
# Created a chunk of size 1453, which is longer than the specified 512
# Created a chunk of size 551, which is longer than the specified 512
# Created a chunk of size 970, which is longer than the specified 512
# Created a chunk of size 720, which is longer than the specified 512
# Created a chunk of size 553, which is longer than the specified 512
# Created a chunk of size 699, which is longer than the specified 512
# Created a chunk of size 519, which is longer than the specified 512
# Created a chunk of size 716, which is longer than the specified 512
# Created a chunk of size 757, which is longer than the specified 512
# Created a chunk of size 560, which is longer than the specified 512
# Created a chunk of size 655, which is longer than the specified 512
# Created a chunk of size 586, which is longer than the specified 512
# Created a chunk of size 783, which is longer than the specified 512
# Created a chunk of size 690, which is longer than the specified 512
# Created a chunk of size 609, which is longer than the specified 512
# Created a chunk of size 629, which is longer than the specified 512
# Created a chunk of size 567, which is longer than the specified 512
# Created a chunk of size 591, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 548, which is longer than the specified 512
# Created a chunk of size 840, which is longer than the specified 512
# Created a chunk of size 568, which is longer than the specified 512
# Created a chunk of size 579, which is longer than the specified 512
# Created a chunk of size 743, which is longer than the specified 512
# Created a chunk of size 626, which is longer than the specified 512
# Created a chunk of size 516, which is longer than the specified 512
# Created a chunk of size 630, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 587, which is longer than the specified 512
# Created a chunk of size 596, which is longer than the specified 512
# Created a chunk of size 1350, which is longer than the specified 512
# Created a chunk of size 547, which is longer than the specified 512
# Created a chunk of size 623, which is longer than the specified 512
# Created a chunk of size 601, which is longer than the specified 512
# Created a chunk of size 586, which is longer than the specified 512
# Created a chunk of size 609, which is longer than the specified 512
# Created a chunk of size 536, which is longer than the specified 512
# Created a chunk of size 607, which is longer than the specified 512
# Created a chunk of size 914, which is longer than the specified 512
# Created a chunk of size 535, which is longer than the specified 512
# Created a chunk of size 603, which is longer than the specified 512
# Created a chunk of size 698, which is longer than the specified 512
# Created a chunk of size 980, which is longer than the specified 512
# Created a chunk of size 702, which is longer than the specified 512
# Created a chunk of size 595, which is longer than the specified 512
# Created a chunk of size 1229, which is longer than the specified 512
# Created a chunk of size 845, which is longer than the specified 512
# Created a chunk of size 1933, which is longer than the specified 512
# Created a chunk of size 1841, which is longer than the specified 512
# Created a chunk of size 594, which is longer than the specified 512
# Created a chunk of size 831, which is longer than the specified 512
# Created a chunk of size 952, which is longer than the specified 512
# Created a chunk of size 531, which is longer than the specified 512
# Created a chunk of size 2007, which is longer than the specified 512
# Created a chunk of size 582, which is longer than the specified 512
# Created a chunk of size 1484, which is longer than the specified 512
# Created a chunk of size 1586, which is longer than the specified 512
# Created a chunk of size 1362, which is longer than the specified 512
# Created a chunk of size 559, which is longer than the specified 512
# Created a chunk of size 614, which is longer than the specified 512
# Created a chunk of size 650, which is longer than the specified 512
# Created a chunk of size 796, which is longer than the specified 512
# Created a chunk of size 1382, which is longer than the specified 512
# Created a chunk of size 793, which is longer than the specified 512
# Created a chunk of size 977, which is longer than the specified 512
# Created a chunk of size 528, which is longer than the specified 512
# Created a chunk of size 1329, which is longer than the specified 512
# Created a chunk of size 595, which is longer than the specified 512
# Created a chunk of size 1279, which is longer than the specified 512
# Created a chunk of size 1076, which is longer than the specified 512
# Created a chunk of size 1251, which is longer than the specified 512
# Created a chunk of size 580, which is longer than the specified 512
# Created a chunk of size 725, which is longer than the specified 512
# Created a chunk of size 1604, which is longer than the specified 512
# Created a chunk of size 1343, which is longer than the specified 512
# Created a chunk of size 2096, which is longer than the specified 512
# Created a chunk of size 686, which is longer than the specified 512
# Created a chunk of size 638, which is longer than the specified 512
# Created a chunk of size 1620, which is longer than the specified 512
# Created a chunk of size 1067, which is longer than the specified 512
# Created a chunk of size 1163, which is longer than the specified 512
# Created a chunk of size 799, which is longer than the specified 512
# Created a chunk of size 1252, which is longer than the specified 512
# Created a chunk of size 561, which is longer than the specified 512
# Created a chunk of size 809, which is longer than the specified 512
# Created a chunk of size 581, which is longer than the specified 512
# Created a chunk of size 666, which is longer than the specified 512
# Created a chunk of size 1301, which is longer than the specified 512
# Created a chunk of size 529, which is longer than the specified 512
# Created a chunk of size 665, which is longer than the specified 512
# Created a chunk of size 573, which is longer than the specified 512
# Created a chunk of size 1182, which is longer than the specified 512
# Created a chunk of size 1091, which is longer than the specified 512
# Created a chunk of size 1130, which is longer than the specified 512
# Created a chunk of size 1141, which is longer than the specified 512
# Created a chunk of size 1226, which is longer than the specified 512
# Created a chunk of size 759, which is longer than the specified 512
# Created a chunk of size 942, which is longer than the specified 512
# Created a chunk of size 529, which is longer than the specified 512
# Created a chunk of size 563, which is longer than the specified 512
# Created a chunk of size 893, which is longer than the specified 512
# Created a chunk of size 710, which is longer than the specified 512
# Created a chunk of size 632, which is longer than the specified 512
# Created a chunk of size 1269, which is longer than the specified 512
# Created a chunk of size 674, which is longer than the specified 512
# Created a chunk of size 612, which is longer than the specified 512
# Created a chunk of size 953, which is longer than the specified 512
# Created a chunk of size 1441, which is longer than the specified 512
# Created a chunk of size 1551, which is longer than the specified 512
# Created a chunk of size 1896, which is longer than the specified 512
# Created a chunk of size 1118, which is longer than the specified 512
# Created a chunk of size 580, which is longer than the specified 512
# Created a chunk of size 913, which is longer than the specified 512
# Created a chunk of size 1163, which is longer than the specified 512
# Created a chunk of size 823, which is longer than the specified 512
# Created a chunk of size 1456, which is longer than the specified 512
# Created a chunk of size 604, which is longer than the specified 512
# Created a chunk of size 742, which is longer than the specified 512
# Created a chunk of size 998, which is longer than the specified 512
# Created a chunk of size 846, which is longer than the specified 512
# Created a chunk of size 910, which is longer than the specified 512
# Created a chunk of size 873, which is longer than the specified 512
# Created a chunk of size 1407, which is longer than the specified 512
# Created a chunk of size 967, which is longer than the specified 512
# Created a chunk of size 719, which is longer than the specified 512
# Created a chunk of size 593, which is longer than the specified 512
# Created a chunk of size 974, which is longer than the specified 512
# Created a chunk of size 1517, which is longer than the specified 512
# Created a chunk of size 972, which is longer than the specified 512
# Created a chunk of size 590, which is longer than the specified 512
# Created a chunk of size 1256, which is longer than the specified 512
# Created a chunk of size 860, which is longer than the specified 512
# Created a chunk of size 777, which is longer than the specified 512
# Created a chunk of size 817, which is longer than the specified 512
# Created a chunk of size 910, which is longer than the specified 512
# Created a chunk of size 2471, which is longer than the specified 512
# Created a chunk of size 546, which is longer than the specified 512
# Created a chunk of size 1696, which is longer than the specified 512
# Created a chunk of size 1607, which is longer than the specified 512
# Created a chunk of size 532, which is longer than the specified 512
# Created a chunk of size 684, which is longer than the specified 512
# Created a chunk of size 668, which is longer than the specified 512
# Created a chunk of size 1246, which is longer than the specified 512
# Created a chunk of size 1135, which is longer than the specified 512
# Created a chunk of size 975, which is longer than the specified 512
# Created a chunk of size 1821, which is longer than the specified 512
# Created a chunk of size 520, which is longer than the specified 512
# Created a chunk of size 580, which is longer than the specified 512
# Created a chunk of size 782, which is longer than the specified 512
# Created a chunk of size 646, which is longer than the specified 512
# Created a chunk of size 768, which is longer than the specified 512
# Created a chunk of size 652, which is longer than the specified 512
# Created a chunk of size 634, which is longer than the specified 512
# Created a chunk of size 740, which is longer than the specified 512
# Created a chunk of size 597, which is longer than the specified 512
# Created a chunk of size 548, which is longer than the specified 512
# Created a chunk of size 718, which is longer than the specified 512
# Created a chunk of size 1525, which is longer than the specified 512
# Created a chunk of size 580, which is longer than the specified 512
# Created a chunk of size 589, which is longer than the specified 512
# Created a chunk of size 627, which is longer than the specified 512
# Created a chunk of size 813, which is longer than the specified 512
# Created a chunk of size 636, which is longer than the specified 512
# Created a chunk of size 534, which is longer than the specified 512
# Created a chunk of size 598, which is longer than the specified 512
# Created a chunk of size 515, which is longer than the specified 512
# Created a chunk of size 600, which is longer than the specified 512
# Created a chunk of size 841, which is longer than the specified 512
# Created a chunk of size 540, which is longer than the specified 512
# Created a chunk of size 718, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 641, which is longer than the specified 512
# Created a chunk of size 550, which is longer than the specified 512
# Created a chunk of size 1082, which is longer than the specified 512
# Created a chunk of size 515, which is longer than the specified 512
# Created a chunk of size 1709, which is longer than the specified 512
# Created a chunk of size 562, which is longer than the specified 512
# Created a chunk of size 1070, which is longer than the specified 512
# Created a chunk of size 910, which is longer than the specified 512
# Created a chunk of size 668, which is longer than the specified 512
# Created a chunk of size 687, which is longer than the specified 512
# Created a chunk of size 743, which is longer than the specified 512
# Created a chunk of size 530, which is longer than the specified 512
# Created a chunk of size 642, which is longer than the specified 512
# Created a chunk of size 566, which is longer than the specified 512
# Created a chunk of size 670, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 597, which is longer than the specified 512
# Created a chunk of size 822, which is longer than the specified 512
# Created a chunk of size 678, which is longer than the specified 512
# Created a chunk of size 746, which is longer than the specified 512
# Created a chunk of size 675, which is longer than the specified 512
# Created a chunk of size 635, which is longer than the specified 512
# Created a chunk of size 651, which is longer than the specified 512
# Created a chunk of size 710, which is longer than the specified 512
# Created a chunk of size 752, which is longer than the specified 512
# Created a chunk of size 677, which is longer than the specified 512
# Created a chunk of size 538, which is longer than the specified 512
# Created a chunk of size 930, which is longer than the specified 512
# Created a chunk of size 670, which is longer than the specified 512
# Created a chunk of size 1390, which is longer than the specified 512
# Created a chunk of size 632, which is longer than the specified 512
# Created a chunk of size 680, which is longer than the specified 512
# Created a chunk of size 864, which is longer than the specified 512
# Created a chunk of size 602, which is longer than the specified 512
# Created a chunk of size 820, which is longer than the specified 512
# Created a chunk of size 4457, which is longer than the specified 512
# Created a chunk of size 765, which is longer than the specified 512
# Created a chunk of size 615, which is longer than the specified 512
# Created a chunk of size 678, which is longer than the specified 512
# Created a chunk of size 540, which is longer than the specified 512
# Created a chunk of size 571, which is longer than the specified 512
# Created a chunk of size 513, which is longer than the specified 512
# Created a chunk of size 548, which is longer than the specified 512
# Created a chunk of size 698, which is longer than the specified 512
# Created a chunk of size 554, which is longer than the specified 512
# Created a chunk of size 583, which is longer than the specified 512
# Created a chunk of size 529, which is longer than the specified 512
# Created a chunk of size 816, which is longer than the specified 512
# Created a chunk of size 576, which is longer than the specified 512
# Created a chunk of size 1871, which is longer than the specified 512
# Created a chunk of size 742, which is longer than the specified 512
# Created a chunk of size 1117, which is longer than the specified 512
# Created a chunk of size 675, which is longer than the specified 512
# Created a chunk of size 595, which is longer than the specified 512
# Created a chunk of size 1055, which is longer than the specified 512
# Created a chunk of size 721, which is longer than the specified 512
# Created a chunk of size 666, which is longer than the specified 512
# Created a chunk of size 612, which is longer than the specified 512
# Created a chunk of size 1379, which is longer than the specified 512
# Created a chunk of size 1142, which is longer than the specified 512
# Created a chunk of size 525, which is longer than the specified 512
# Created a chunk of size 697, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 821, which is longer than the specified 512
# Created a chunk of size 682, which is longer than the specified 512
# Created a chunk of size 1200, which is longer than the specified 512
# Created a chunk of size 652, which is longer than the specified 512
# Created a chunk of size 735, which is longer than the specified 512
# Created a chunk of size 544, which is longer than the specified 512
# Created a chunk of size 649, which is longer than the specified 512
# Created a chunk of size 1566, which is longer than the specified 512
# Created a chunk of size 936, which is longer than the specified 512
# Created a chunk of size 554, which is longer than the specified 512
# Created a chunk of size 904, which is longer than the specified 512
# Created a chunk of size 923, which is longer than the specified 512
# Created a chunk of size 570, which is longer than the specified 512
# Created a chunk of size 581, which is longer than the specified 512
# Created a chunk of size 1303, which is longer than the specified 512
# Created a chunk of size 535, which is longer than the specified 512
# Created a chunk of size 623, which is longer than the specified 512
# Created a chunk of size 1624, which is longer than the specified 512
# Created a chunk of size 559, which is longer than the specified 512
# Created a chunk of size 595, which is longer than the specified 512
# Created a chunk of size 635, which is longer than the specified 512
# Created a chunk of size 534, which is longer than the specified 512
# Created a chunk of size 610, which is longer than the specified 512
# Created a chunk of size 563, which is longer than the specified 512
# Created a chunk of size 526, which is longer than the specified 512
# Created a chunk of size 566, which is longer than the specified 512
# Created a chunk of size 742, which is longer than the specified 512
# Created a chunk of size 1102, which is longer than the specified 512
# Created a chunk of size 1230, which is longer than the specified 512
# Created a chunk of size 782, which is longer than the specified 512
# Created a chunk of size 626, which is longer than the specified 512
# Created a chunk of size 548, which is longer than the specified 512
# Created a chunk of size 900, which is longer than the specified 512
# Created a chunk of size 517, which is longer than the specified 512
# Created a chunk of size 560, which is longer than the specified 512

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings.openai import OpenAIEmbeddings

embedding= OpenAIEmbeddings()

# %%
embeddings_vectors = FAISS.from_documents(nlp_texts,embedding)

# %% [markdown]
# ## Ingest the index

# %%
# Delete all documents
es.delete_by_query(index=index_name, body={"query": {"match_all": {}}})
# Out:
# ObjectApiResponse({'took': 56, 'timed_out': False, 'total': 237, 'deleted': 237, 'batches': 1, 'version_conflicts': 0, 'noops': 0, 'retries': {'bulk': 0, 'search': 0}, 'throttled_millis': 0, 'requests_per_second': -1.0, 'throttled_until_millis': 0, 'failures': []})

# %%
# add to the elastic search each chunk with their embeddings, text and metadata
from tqdm import tqdm

page_count = 0
curr_doc = None
for i, doc in tqdm(enumerate(nlp_texts), total=len(nlp_texts), desc='Indexing Documents'):
    if curr_doc != doc.metadata['source']:
        page_count = 0
        curr_doc = doc.metadata['source']
    else:
        page_count += 1
    es.index(index=index_name, body={"vector": embeddings_vectors.index.reconstruct_n(i, 1)[0], 
                                     "text": doc.page_content, 
                                     "metadata": {"id":(doc.metadata['source']+"_"+str(page_count)),"source": doc.metadata['source'], "page": doc.metadata['page']}
                                     })
# Out:
# Indexing Documents: 100%|██████████| 4372/4372 [09:17<00:00,  7.85it/s]
